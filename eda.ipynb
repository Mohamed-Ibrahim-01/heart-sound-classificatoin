# %%
from feature_extraction import construct_dataframe

# %%
hs_df = construct_dataframe()

# %%
hs_df.head()
# Out:
#    Max_Amplitude  Dominant_Freq   Entropy       Mean  Median          STD  \
# 0        12446.0          42.00  7.350157  13.274000    -3.5  1683.647583
# 1        26525.0          80.50  7.659120 -18.436562   -57.0  3462.921387
# 2        24026.0          77.25  7.550494 -16.397499   -30.0  3605.023926
# 3        32767.0          67.75  7.902097  16.315125    31.5  4866.672363
# 4        32767.0          86.75  7.664650   8.744813    50.5  4236.488770
#
#     Kurtosis  Skewness      IQR  First_Percentile  ...     MFCC5      MFCC6  \
# 0  16.358456  0.288123   931.25           -463.00  ...  6.707300  25.834023
# 1  14.751706  0.581497  1196.25           -648.25  ...  0.352715  28.612226
# 2  15.507599  0.076393  1064.25           -586.00  ...  3.096638  28.063137
# 3  20.778270 -0.439780  1866.00           -921.00  ...  6.428962  20.405239
# 4  24.432427  1.328203  1403.00           -671.00  ...  6.894861  23.845081
#
# ...

# %%
# %matplotlib inline
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math

nor_df = hs_df[hs_df["Label"] == "normal"]
mur_df = hs_df[hs_df["Label"] == "murmur"]
extr_df = hs_df[hs_df["Label"] == "extrasystole"]

dfs = [nor_df, mur_df, extr_df]

features_names = df.columns
fig, axs = plt.subplots(nrows=9, ncols=3, figsize=(20,35), gridspec_kw={'hspace': 0.3})
for df in dfs:
    for i, feature in enumerate(features_names):
        ax = axs[math.floor(i/3)][i%3]
        ax.hist(df[feature], bins=20)
        ax.set(title=feature)
plt.show()
